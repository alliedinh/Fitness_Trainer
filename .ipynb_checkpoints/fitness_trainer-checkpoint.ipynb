# %%
# Suppress warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['GLOG_minloglevel'] = '3'
os.environ['MEDIAPIPE_DISABLE_GPU'] = '1'

# %%
# Import packages
import cv2
import shutil
import json
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python.vision import PoseLandmarker, PoseLandmarkerOptions
from mediapipe.tasks.python import BaseOptions
import pandas as pd
from tqdm import tqdm
import urllib.request
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
# Configure directories
UCF_VIDEOS = "UCF-101"
UCF_SPLITS = "UCF101TrainTestSplits/ucfTrainTestlist"
FRAMES_DIR = "outputs/frames"
KEYPOINTS_DIR = "outputs/keypoints"

# Convert UCF101 classes to our labels
EXERCISE_CLASSES = {
    "PushUps": "pushups", 
    "BodyWeightSquats": "squats",
    "Lunges": "lunges",
    "PullUps": "pullups",
}

# Configure desired frame rates and image size
TARGET_FPS = 10
IMG_SIZE = (640, 480)

# %%
# Filter 5 classes from the train/test split
def load_videos():
    rows = []
    for split, filename in [("train", "trainlist01.txt"), ("test", "testlist01.txt")]:
        filepath = os.path.join(UCF_SPLITS, filename)
        with open(filepath) as f:
            for line in f: # e.g. BodyWeightSquats/v_BodyWeightSquats_g08_c01.avi
                rel_path = line.strip().split()[0]
                class_name = rel_path.split("/")[0]
                if class_name not in EXERCISE_CLASSES:
                    continue
                rows.append({
                    "video_path": os.path.join(UCF_VIDEOS, rel_path),
                    "label": EXERCISE_CLASSES[class_name],
                    "split": split,
                    "video_name": os.path.splitext(os.path.basename(rel_path))[0]
                })
    df = pd.DataFrame(rows)
    print(f"Found {len(df)} exercise videos\n{df['label'].value_counts()}\n")
    return df

# %%
# Name keypoints according to MediaPipe Pose standards
KEYPOINT_NAMES = [
    "nose", "left_eye_inner", "left_eye", "left_eye_outer",
    "right_eye_inner", "right_eye", "right_eye_outer",
    "left_ear", "right_ear", "mouth_left", "mouth_right",
    "left_shoulder", "right_shoulder", "left_elbow", "right_elbow",
    "left_wrist", "right_wrist", "left_pinky", "right_pinky",
    "left_index", "right_index", "left_thumb", "right_thumb",
    "left_hip", "right_hip", "left_knee", "right_knee",
    "left_ankle", "right_ankle", "left_heel", "right_heel",
    "left_foot_index", "right_foot_index",
]

# Download the MediaPipe Pose model
MODEL_PATH = "pose_landmarker.task"
if not os.path.exists(MODEL_PATH):
    print("Downloading pose model...")
    urllib.request.urlretrieve(
        "https://storage.googleapis.com/mediapipe-models/pose_landmarker/pose_landmarker_full/float16/latest/pose_landmarker_full.task",
        MODEL_PATH
    )
    print("Downloaded!")
    
def extract_frames_and_keypoints(video_df, save_every=50):
    os.makedirs(KEYPOINTS_DIR, exist_ok=True)

    checkpoint_path = "outputs/keypoints/checkpoint.csv"
    if os.path.exists(checkpoint_path):
        completed_df = pd.read_csv(checkpoint_path)
        completed = set(completed_df["video_name"].unique())
        print(f"Resuming — {len(completed)} videos already done")
        # Don't keep completed_df in memory
        del completed_df
    else:
        completed = set()

    options = PoseLandmarkerOptions(
        base_options=BaseOptions(model_asset_path=MODEL_PATH),
        running_mode=mp.tasks.vision.RunningMode.IMAGE,
        num_poses=1,
        min_pose_detection_confidence=0.5,
    )

    batch_rows = [] # Only keep current batch in memory
    videos_done = 0

    with PoseLandmarker.create_from_options(options) as landmarker:
        for _, video_row in tqdm(video_df.iterrows(), total=len(video_df),
                                 desc="Processing videos"):

            if video_row["video_name"] in completed:
                continue

            save_dir = os.path.join(FRAMES_DIR, video_row["split"],
                                    video_row["label"], video_row["video_name"])
            os.makedirs(save_dir, exist_ok=True)

            # ── Extract frames ────────────────────────────────
            cap = cv2.VideoCapture(video_row["video_path"])
            fps = cap.get(cv2.CAP_PROP_FPS) or TARGET_FPS
            frame_interval = max(1, int(round(fps / TARGET_FPS)))
            frame_idx, saved_idx = 0, 0
            frame_paths = []

            while True:
                ret, frame = cap.read()
                if not ret:
                    break
                if frame_idx % frame_interval == 0:
                    frame_path = os.path.join(save_dir, f"frame_{saved_idx:04d}.jpg")
                    cv2.imwrite(frame_path, cv2.resize(frame, IMG_SIZE))
                    frame_paths.append({
                        **video_row.to_dict(),
                        "frame_path": frame_path,
                        "frame_index": saved_idx
                    })
                    saved_idx += 1
                frame_idx += 1
            cap.release()

            # Extract keypoints
            for frame_data in frame_paths:
                frame = cv2.imread(frame_data["frame_path"])
                if frame is None:
                    continue
                rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb)
                results = landmarker.detect(mp_image)
                if not results.pose_landmarks:
                    continue
                landmarks = results.pose_landmarks[0]
                keypoints = {}
                for i, name in enumerate(KEYPOINT_NAMES):
                    kp = landmarks[i]
                    keypoints[f"{name}_x"] = round(kp.x, 6)
                    keypoints[f"{name}_y"] = round(kp.y, 6)
                batch_rows.append({
                    "frame_path": frame_data["frame_path"],
                    "video_name": frame_data["video_name"],
                    "label": frame_data["label"],
                    "split": frame_data["split"],
                    "frame_index": frame_data["frame_index"],
                    **keypoints
                })

            # Delete frames immediately
            shutil.rmtree(save_dir, ignore_errors=True)
            completed.add(video_row["video_name"])
            videos_done += 1

            # Save batch and clear memory every N videos
            if videos_done % save_every == 0:
                batch_df = pd.DataFrame(batch_rows)
                # Append to checkpoint
                write_header = not os.path.exists(checkpoint_path)
                batch_df.to_csv(checkpoint_path, mode="a",
                                header=write_header, index=False)
                print(f"checkpoint saved — {videos_done} videos done, "
                      f"{len(batch_rows)} rows flushed")
                batch_rows = [] # Clear memory
                import gc
                gc.collect()

    # Save any remaining rows 
    if batch_rows:
        batch_df = pd.DataFrame(batch_rows)
        write_header = not os.path.exists(checkpoint_path)
        batch_df.to_csv(checkpoint_path, mode="a",
                        header=write_header, index=False)
        batch_rows = []

    # Load checkpoint and save final CSVs
    print("Saving final CSVs...")
    full_df = pd.read_csv(checkpoint_path)
    for split, group in full_df.groupby("split"):
        out_path = os.path.join(KEYPOINTS_DIR, f"{split}_keypoints.csv")
        group.to_csv(out_path, index=False)
        print(f"Saved {len(group)} rows → {out_path}")
        print(group["label"].value_counts(), "\n")

    os.remove(checkpoint_path)
    print("Done!")
    return full_df

# %% [markdown]
# # Data Loading and Preprocessing

# %% [markdown]
# ### We also included scraping of YouTube videos since our original dataset, although diverse, didn't provide enough data for the models to effectively train on.

# %% [markdown]
# Note: This cell is only ran once to extract frames and keypoints from videos using MediaPipe Pose. Outputs are saved under /outputs/frames and /outputs/keypoints.

# %%
import subprocess
import sys

# %%
# Download YouTube videos first (run once)
# Install yt-dlp
subprocess.run([sys.executable, "-m", "pip", "install", "yt-dlp", "--break-system-packages"])
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yt-dlp in /home/amchahal/.local/lib/python3.11/site-packages (2026.3.3)
# CompletedProcess(args=['/opt/conda/bin/python', '-m', 'pip', 'install', 'yt-dlp', '--break-system-packages'], returncode=0)

# %%
import yt_dlp

def download_youtube_videos(query, out_dir, max_downloads=8):
    os.makedirs(out_dir, exist_ok=True)
    ydl_opts = {
        "format": "mp4/bestvideo[ext=mp4]", "outtmpl": f"{out_dir}/%(title)s.%(ext)s",
        "max_filesize": 20 * 1024 * 1024, # 20 MB
        "noplaylist": True,
        "ignoreerrors": True,
        "quiet": False,
        "download_ranges": lambda info, _: [{"start_time": 0, "end_time": 45}],  # 45 sec max
        "force_keyframes_at_cuts": True
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([f"ytsearch{max_downloads}:{query}"])

# Download all exercises
QUERIES = [
    ("squat form tutorial side view", "data/youtube/squats"),
    ("squat form tutorial front view", "data/youtube/squats"),
    ("lunge form tutorial side view", "data/youtube/lunges"),
    ("pushup form tutorial side view", "data/youtube/pushups"),
    ("pullup form tutorial side view", "data/youtube/pullups")
]

for query, out_dir in QUERIES:
    print(f"\nDownloading: {query}")
    download_youtube_videos(query, out_dir, max_downloads=10)
# Out:
# Downloading: squat form tutorial side view
# [youtube:search] Extracting URL: ytsearch10:squat form tutorial side view
# [download] Downloading playlist: squat form tutorial side view
# [youtube:search] query "squat form tutorial side view": Downloading web client config
# [youtube:search] query "squat form tutorial side view" page 1: Downloading API JSON
# [youtube:search] Playlist squat form tutorial side view: Downloading 10 items of 10
# [download] Downloading item 1 of 10
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gcNh17Ckjgg
# [youtube] gcNh17Ckjgg: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] gcNh17Ckjgg: Downloading android vr player API JSON
# [info] gcNh17Ckjgg: Downloading 1 format(s): 18
# [info] gcNh17Ckjgg: Downloading 1 time ranges: 0.0-45.0
# [download] Destination: data/youtube/squats/How to PROPERLY Squat for Growth (4 Easy Steps).mp4
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr1---sn-jxopj-n5oe.googlevideo.com/videoplayback?expire=1773319222&ei=1l-yaciULKOLsfIP95zfwQ0&ip=137.110.217.41&id=o-ANJdPtRlQp7OE5P-I8tNyIhlzu9R971UotHQkayyjlto&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&cps=293&met=1773297622%2C&mh=wO&mm=31%2C29&mn=sn-jxopj-n5oe%2Csn-a5mekndk&ms=au%2Crdu&mv=m&mvi=1&pcm2cms=yes&pl=20&rms=au%2Cau&initcwndbps=2900000&bui=AVNa5-ys87BZTXsb5dr9Y8ty1ncZFK1pPDcYZt8H7Ddu04q8aU3CGQuOEBiL6N0hoJWm_UU4iH7U0rvG&spc=6dlaFDYekBtazgmbe3so-kd8t8FYfZbVOsIBDI1mArWzPcUOAvHZBgqC&vprv=1&svpuc=1&mime=video%2Fmp4&rqh=1&cnr=14&ratebypass=yes&dur=435.025&lmt=1753087783293533&mt=1773297177&fvip=4&fexp=51565115%2C51565682%2C51791334&c=ANDROID_VR&txp=5538534&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cbui%2Cspc%2Cvprv%2Csvpuc%2Cmime%2Crqh%2Ccnr%2Cratebypass%2Cdur%2Clmt&sig=AHEqNM4wRAIgVP3LuS4Auxi5isT7GX_CGTidrEfrk6SOOz3J1hJ1HesCIGkR3HXCkEjBtY3cDqoC1r1pYDXzICFkYTJHjKBehPqf&lsparams=cps%2Cmet%2Cmh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Crms%2Cinitcwndbps&lsig=APaTxxMwRgIhALt4Onf9BzyKV4xQsz__ShNk1FIwHj94pAuSMYkZWQYHAiEA6pvDunZ5EBCQ_k4Go-YE2xkk2bKrM6g435HH2Kk3a8Q%3D':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2025-07-21T05:16:34.000000Z
#     encoder         : Google
#   Duration: 00:07:14.98, start: 0.000000, bitrate: 273 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 141 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2025-07-21T05:16:34.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 07/20/2025.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2025-07-21T05:16:34.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 07/20/2025.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x556b53598440] using SAR=1/1
# [libx264 @ 0x556b53598440] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x556b53598440] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x556b53598440] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'file:data/youtube/squats/How to PROPERLY Squat for Growth (4 Easy Steps).mp4.part':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       creation_time   : 2025-07-21T05:16:34.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 07/20/2025.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2025-07-21T05:16:34.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 07/20/2025.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame= 1324 fps=174 q=29.0 size=    2304kB time=00:00:44.14 bitrate= 427.6kbits/s speed=5.78x
# [download] 100% of    2.67MiB in 00:00:08 at 332.24KiB/s
# [download] Downloading item 2 of 10
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Wea2NrbkBhQ
# [youtube] Wea2NrbkBhQ: Downloading webpage
# frame= 1349 fps=170 q=-1.0 Lsize=    2738kB time=00:00:44.97 bitrate= 498.7kbits/s speed=5.67x
# video:1973kB audio:716kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.789318%
# [libx264 @ 0x556b53598440] frame I:19    Avg QP:19.18  size: 16454
# [libx264 @ 0x556b53598440] frame P:520   Avg QP:23.69  size:  2527
# [libx264 @ 0x556b53598440] frame B:810   Avg QP:28.46  size:   486
# [libx264 @ 0x556b53598440] consecutive B-frames:  7.3% 30.4% 22.2% 40.0%
# [libx264 @ 0x556b53598440] mb I  I16..4: 17.4% 42.3% 40.3%
# [libx264 @ 0x556b53598440] mb P  I16..4:  3.2%  4.6%  1.4%  P16..4: 25.9%  8.2%  2.9%  0.0%  0.0%    skip:53.8%
# [libx264 @ 0x556b53598440] mb B  I16..4:  0.1%  0.1%  0.0%  B16..8: 22.2%  2.2%  0.3%  direct: 0.3%  skip:74.9%  L0:39.5% L1:54.1% BI: 6.4%
# [libx264 @ 0x556b53598440] 8x8 transform intra:47.8% inter:61.1%
# [libx264 @ 0x556b53598440] coded y,uvDC,uvAC intra: 44.4% 52.0% 24.9% inter: 4.0% 5.0% 0.8%
# [libx264 @ 0x556b53598440] i16 v,h,dc,p: 25% 46%  8% 21%
# [libx264 @ 0x556b53598440] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 33% 22%  3%  2%  2%  4%  3%  4%
# [libx264 @ 0x556b53598440] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 30% 13%  4%  4%  4%  5%  4%  4%
# [libx264 @ 0x556b53598440] i8c dc,h,v,p: 45% 28% 20%  7%
# [libx264 @ 0x556b53598440] Weighted P-Frames: Y:1.7% UV:0.4%
# [libx264 @ 0x556b53598440] ref P L0: 67.4% 18.3% 10.4%  3.9%  0.1%
# [libx264 @ 0x556b53598440] ref B L0: 88.3% 10.4%  1.3%
# [libx264 @ 0x556b53598440] ref B L1: 98.5%  1.5%
# [libx264 @ 0x556b53598440] kb/s:359.04
# [aac @ 0x556b53599540] Qavg: 280.764
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Wea2NrbkBhQ: Downloading android vr player API JSON
# ERROR: [youtube] Wea2NrbkBhQ: This video is not available
# [download] Downloading item 3 of 10
# [youtube] Extracting URL: https://www.youtube.com/watch?v=txnwoJz-Rno
# [youtube] txnwoJz-Rno: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] txnwoJz-Rno: Downloading android vr player API JSON
# [info] txnwoJz-Rno: Downloading 1 format(s): 18
# [info] txnwoJz-Rno: Downloading 1 time ranges: 0.0-45.0
# [download] Destination: data/youtube/squats/Back Squat - Side View.mp4
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr1---sn-jxopj-n5oe.googlevideo.com/videoplayback?expire=1773319233&ei=4V-yaerNH-WDt7EPp9Wu-A4&ip=137.110.217.41&id=o-AOB7EgUVa68mabxz-knKATNuMcVRo2gZqeg-nEkK3vFb&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&cps

#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Google
#   Duration: 00:08:21.97, start: 0.000000, bitrate: 442 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 344 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5557d5bf5200] using SAR=1/1
# [libx264 @ 0x5557d5bf5200] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5557d5bf5200] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x5557d5bf5200] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=11 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'file:data/youtube/pullups/How To Get MORE Gains From Pull-Ups (4 Mistakes You Need To Fix).mp4.part':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 640x360 [SAR 1:1 DAR 16:9], q=2-31, 29.97 fps, 30k tbn (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame= 1280 fps=148 q=29.0 size=    2816kB time=00:00:42.74 bitrate= 539.7kbits/s speed=4.95x
# [download] 100% of    3.27MiB in 00:00:09 at 354.29KiB/s
# [download] Downloading item 10 of 10
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Hdc7Mw6BIEE
# [youtube] Hdc7Mw6BIEE: Downloading webpage
# frame= 1349 fps=148 q=-1.0 Lsize=    3350kB time=00:00:44.97 bitrate= 610.2kbits/s speed=4.93x
# video:2595kB audio:707kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.452975%
# [libx264 @ 0x5557d5bf5200] frame I:18    Avg QP:21.24  size: 14144
# [libx264 @ 0x5557d5bf5200] frame P:486   Avg QP:23.59  size:  3571
# [libx264 @ 0x5557d5bf5200] frame B:845   Avg QP:29.64  size:   789
# [libx264 @ 0x5557d5bf5200] consecutive B-frames: 13.1%  7.3%  8.5% 71.2%
# [libx264 @ 0x5557d5bf5200] mb I  I16..4: 24.6% 41.0% 34.5%
# [libx264 @ 0x5557d5bf5200] mb P  I16..4:  3.6%  4.0%  1.4%  P16..4: 27.7% 11.3%  5.3%  0.0%  0.0%    skip:46.7%
# [libx264 @ 0x5557d5bf5200] mb B  I16..4:  0.2%  0.2%  0.1%  B16..8: 29.7%  3.2%  0.6%  direct: 0.6%  skip:65.4%  L0:47.9% L1:45.3% BI: 6.7%
# [libx264 @ 0x5557d5bf5200] 8x8 transform intra:43.2% inter:64.3%
# [libx264 @ 0x5557d5bf5200] coded y,uvDC,uvAC intra: 49.4% 67.6% 35.9% inter: 7.2% 11.9% 2.3%
# [libx264 @ 0x5557d5bf5200] i16 v,h,dc,p: 25% 53%  6% 15%
# [libx264 @ 0x5557d5bf5200] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 29% 16%  3%  4%  4%  5%  4%  6%
# [libx264 @ 0x5557d5bf5200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 28% 10%  4%  5%  6%  6%  5%  5%
# [libx264 @ 0x5557d5bf5200] i8c dc,h,v,p: 37% 30% 25%  8%
# [libx264 @ 0x5557d5bf5200] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5557d5bf5200] ref P L0: 73.1% 12.2% 12.4%  2.3%
# [libx264 @ 0x5557d5bf5200] ref B L0: 95.0%  4.5%  0.5%
# [libx264 @ 0x5557d5bf5200] ref B L1: 98.1%  1.9%
# [libx264 @ 0x5557d5bf5200] kb/s:472.24
# [aac @ 0x5557d5bfc540] Qavg: 308.093
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Hdc7Mw6BIEE: Downloading android vr player API JSON
# [info] Hdc7Mw6BIEE: Downloading 1 format(s): 18
# [info] Hdc7Mw6BIEE: Downloading 1 time ranges: 0.0-45.0
# [download] Destination: data/youtube/pullups/The Best Way To Do Pull Ups For A Wide Back (Optimal Training Technique).mp4
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr3---sn-jxopj-n5oe.googlevideo.com/videoplayback?expire=1773319582&ei=PWGyaYvXPKHtsfIPwuqhgAg&ip=137.110.217.41&id=o-AC0O4LvsvcGFKrRz7URcAF2uirORjfkZ6RK4HTT2PhT8&itag=18&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D
] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 23% 23%  3%  4%  4%  4%  3%  4%
# [libx264 @ 0x56359df45180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 24% 11%  4%  5%  6%  5%  5%  4%
# [libx264 @ 0x56359df45180] i8c dc,h,v,p: 64% 17% 17%  3%
# [libx264 @ 0x56359df45180] Weighted P-Frames: Y:2.7% UV:1.1%
# [libx264 @ 0x56359df45180] ref P L0: 74.7% 11.4% 10.5%  3.2%  0.1%
# [libx264 @ 0x56359df45180] ref B L0: 92.1%  6.9%  0.9%
# [libx264 @ 0x56359df45180] ref B L1: 97.3%  2.7%
# [libx264 @ 0x56359df45180] kb/s:273.90
# [aac @ 0x56359e036440] Qavg: 274.485

# %%
import re

def sanitize_name(name):
    # Remove special characters that cause filesystem issues
    name = re.sub(r"[^\w\s-]", "", name)   # Keep only alphanumeric, spaces, hyphens
    name = re.sub(r"\s+", "_", name)        # Replace spaces with underscores
    return name[:80]
    
def load_youtube_videos(youtube_dir, split="train"):
    rows = []
    for label in ["squats", "lunges", "pushups", "pullups"]:
        folder = os.path.join(youtube_dir, label)
        if not os.path.exists(folder):
            continue
        for video_file in os.listdir(folder):
            if video_file.endswith(".mp4") or video_file.endswith(".webm"):
                rows.append({
                    "video_path": os.path.join(folder, video_file),
                    "label": label,
                    "split": split,
                    "video_name": sanitize_name(os.path.splitext(video_file)[0])
                })
    df = pd.DataFrame(rows)
    if len(df) == 0:
        print("No YouTube videos found — check data/youtube folder exists")
    else:
        print(f"Found {len(df)} YouTube videos")
        print(df["label"].value_counts())
    return df

# %%
# Load all videos
ucf_df = load_videos()   # UCF-101 loader
yt_df = load_youtube_videos("data/youtube")
video_df = pd.concat([ucf_df, yt_df]).reset_index(drop=True)

print(f"Total videos: {len(video_df)}")
print(video_df["label"].value_counts())

extract_frames_and_keypoints(video_df)

# Delete frames after keypoints have been extracted (avoid hitting disk quota)
shutil.rmtree("outputs/frames", ignore_errors=True)
print("Frames deleted — keypoints saved")
# Out:
# Found 441 exercise videos
# label
# lunges     127
# squats     112
# pushups    102
# pullups    100
# Name: count, dtype: int64
#
# Found 30 YouTube videos
# label
# squats     10
# pushups     8
# pullups     8
# lunges      4
# Name: count, dtype: int64
# Total videos: 471
# label
# lunges     131
# squats     122
# pushups    110
# pullups    108
# Name: count, dtype: int64
# Resuming — 439 videos already done
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1773298725.097186     495 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1773298725.172517     503 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Processing videos:  74%|███████▍  | 348/471 [00:06<00:02, 50.21it/s]W0000 00:00:1773298733.391848     512 landmark_projection_calculator.cc:78] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# Processing videos: 100%|██████████| 471/471 [25:15<00:00,  3.22s/it]
# Saving final CSVs...
# Saved 6682 rows → outputs/keypoints/test_keypoints.csv
# label
# lunges     2953
# squats     1812
# pushups     980
# pullups     937
# Name: count, dtype: int64
#
# Saved 29548 rows → outputs/keypoints/train_keypoints.csv
# label
# lunges     10221
# squats      8680
# pullups     5765
# pushups     4882
# Name: count, dtype: int64
#
# Done!
# Frames deleted — keypoints saved

# %%
# Delete unnecessary keypoints
useful_keypoints = [
    "left_shoulder", "right_shoulder", "left_elbow", "right_elbow",
    "left_wrist", "right_wrist", "left_hip", "right_hip",
    "left_knee", "right_knee", "left_ankle", "right_ankle", 
    "nose", "left_ear", "right_ear"
]

train_df = pd.read_csv("outputs/keypoints/train_keypoints.csv")
keep_cols = ["frame_path", "video_name", "label", "split", "frame_index"]
for kp in useful_keypoints:
    keep_cols += [f"{kp}_x", f"{kp}_y"]

train_df = train_df[keep_cols]
train_df.to_csv("outputs/keypoints/train_keypoints.csv", index=False)

test_df = pd.read_csv("outputs/keypoints/test_keypoints.csv")
keep_cols = ["frame_path", "video_name", "label", "split", "frame_index"]
for kp in useful_keypoints:
    keep_cols += [f"{kp}_x", f"{kp}_y"]

test_df = test_df[keep_cols]
test_df.to_csv("outputs/keypoints/test_keypoints.csv", index=False)

# %% [markdown]
# ## Feature Computation and Labeling

# %%
def compute_angle(a, b, c):
    # Angle at point b, formed by a-b-c
    a, b, c = np.array(a), np.array(b), np.array(c)
    ba = a - b
    bc = c - b
    cos_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc) + 1e-8)
    return np.degrees(np.arccos(np.clip(cos_angle, -1.0, 1.0)))

def compute_torso_angle(row):
    shoulder_mid_x = (row["left_shoulder_x"] + row["right_shoulder_x"]) / 2
    shoulder_mid_y = (row["left_shoulder_y"] + row["right_shoulder_y"]) / 2
    hip_mid_x = (row["left_hip_x"] + row["right_hip_x"]) / 2
    hip_mid_y = (row["left_hip_y"] + row["right_hip_y"]) / 2

    # Vector from hip to shoulder
    dx = shoulder_mid_x - hip_mid_x
    dy = shoulder_mid_y - hip_mid_y  # note: y increases downward in image coords

    # Angle from vertical (0° = up)
    angle = np.degrees(np.arctan2(abs(dx), abs(dy)))
    return angle
    
def add_angles(df):
    def angle(r, a, b, c):
        # Helper to pull x/y from row and compute angle at b
        return compute_angle(
            (r[f"{a}_x"], r[f"{a}_y"]),
            (r[f"{b}_x"], r[f"{b}_y"]),
            (r[f"{c}_x"], r[f"{c}_y"])
        )

    # KNEE ANGLES (squats, lunges) 
    for side in ["left", "right"]:
        df[f"{side}_knee_angle"] = df.apply(
            lambda r, s=side: angle(r, f"{s}_hip", f"{s}_knee", f"{s}_ankle"), axis=1)

    # ELBOW ANGLES (push-ups, pull-ups)
    for side in ["left", "right"]:
        df[f"{side}_elbow_angle"] = df.apply(
            lambda r, s=side: angle(r, f"{s}_shoulder", f"{s}_elbow", f"{s}_wrist"), axis=1)

    # HIP ANGLES (squats, lunges, pull-ups)
    for side in ["left", "right"]:
        df[f"{side}_hip_angle"] = df.apply(
            lambda r, s=side: angle(r, f"{s}_shoulder", f"{s}_hip", f"{s}_knee"), axis=1)

    # BODY LINE / HIP SAG (push-ups)
    for side in ["left", "right"]:
        df[f"{side}_body_line"] = df.apply(
            lambda r, s=side: angle(r, f"{s}_shoulder", f"{s}_hip", f"{s}_ankle"), axis=1)

    # TORSO UPRIGHTNESS (lunges, squats)
    # Angle between vertical and the shoulder-hip vector
    df["torso_angle"] = df.apply(compute_torso_angle, axis=1)

    # KNEE BEND (squats, lunges)
    # How far knee is inside/outside the ankle - not an angle, just a distance
    for side in ["left", "right"]:
        df[f"{side}_knee_bend"] = df[f"{side}_knee_x"] - df[f"{side}_ankle_x"]

    # HEAD DROP (push-ups) 
    df["head_drop"] = df["nose_y"] - df["left_shoulder_y"]

    # SHOULDER SHRUG (pull-ups)
    for side in ["left", "right"]:
        df[f"{side}_shoulder_shrug"] = df[f"{side}_ear_y"] - df[f"{side}_shoulder_y"]

    # SHOULDER ANGLE (pull-ups)
    for side in ["left", "right"]:
        df[f"{side}_shoulder_angle"] = df.apply(
        lambda r, s=side: angle(r, f"{s}_elbow", f"{s}_shoulder", f"{s}_hip"), axis=1)
    return df

# %%
def detect_orientation(row):
    shoulder_sep = abs(row["left_shoulder_x"] - row["right_shoulder_x"])
    hip_sep = abs(row["left_hip_x"] - row["right_hip_x"])
    avg_sep = (shoulder_sep + hip_sep) / 2
    return "front" if avg_sep > 0.08 else "side"

def label_form(row):
    label = row.get("label")
    orientation = detect_orientation(row)
    
    lk = row.get("left_knee_angle", 180)
    rk = row.get("right_knee_angle", 180)
    le = row.get("left_elbow_angle", 180)
    re = row.get("right_elbow_angle", 180)
    lbl = row.get("left_body_line", 180)
    rbl = row.get("right_body_line", 180)
    tor = row.get("torso_angle", 0)
    lkb = row.get("left_knee_bend", 0)
    rkb = row.get("right_knee_bend", 0)
    lss = row.get("left_shoulder_shrug", 0)
    rss = row.get("right_shoulder_shrug", 0)
    hd = row.get("head_drop", 0)
    lh = row.get("left_hip_angle", 180)
    rh = row.get("right_hip_angle", 180)

    min_knee = min(lk, rk)
    min_elbow = min(le, re)
    knee_sym = abs(lk - rk)
    elbow_sym = abs(le - re)
    avg_body_line = (lbl + rbl) / 2
    avg_shrug = (lss + rss) / 2

    # Filter out bad landmark detections
    # 180° means MediaPipe lost the joint
    if min_knee > 179 or min_elbow > 179:
        return None

    # SQUATS
    # Good = clearly bent (bottom) or clearly straight (top)
    # Accounts for all frames in a 'good' squat 
    if label == "squats":
        at_bottom = min_knee < 130        
        at_top = min_knee > 165        
        if not (at_bottom or at_top):
            return "bad"

        leaning = tor > 30
        knee_cave = (lkb < -0.04 or rkb < -0.04)

        # Checks based on orientation w.r.t camera
        if orientation == "front":
            asymmetric = knee_sym > 25
            return "bad" if (leaning or knee_cave or asymmetric) else "good"
        else:
            return "bad" if (leaning or knee_cave) else "good"

    # PUSHUPS
    # Accounts for all frames in a 'good' pushup 
    elif label == "pushups":
        at_bottom = min_elbow < 120       
        at_top = min_elbow > 155
        if not (at_bottom or at_top):
            return "bad"

        hip_sag = avg_body_line < 145
        head_down = hd > 0.12
        asymmetric = elbow_sym > 25

        # Checks based on orientation w.r.t camera
        if orientation == "front":
            return "bad" if (hip_sag or head_down or asymmetric) else "good"
        else:
            return "bad" if (hip_sag or head_down) else "good"

    # LUNGES
    # Accounts for all frames in a 'good' lunge
    elif label == "lunges":
        at_top = min_knee > 165
        at_depth = min_knee < 140         

        if not (at_top or at_depth):
            return "bad"

        leaning = tor > 20
        knee_over = (lkb > 0.08 or rkb > 0.08)

        # Checks based on orientation w.r.t camera
        if orientation == "front":
            naturally_asym = knee_sym > 15
            return "bad" if (leaning or knee_over or not naturally_asym) else "good"
        else:
            return "bad" if (leaning or knee_over) else "good"

    # PULLUPS
    # Accounts for all frames in a 'good' pullup
    elif label == "pullups":
        at_top = min_elbow < 110         
        at_hang = min_elbow > 150
        if not (at_top or at_hang):
            return "bad"

        shrugging = avg_shrug > -0.05
        asymmetric = elbow_sym > 20
        swinging = abs(lh - rh) > 30

        # Checks based on orientation w.r.t camera
        if orientation == "front":
            return "bad" if (shrugging or asymmetric or swinging) else "good"
        else:
            return "bad" if (shrugging or swinging) else "good"

    return None

def apply_labels(df):
    df = add_angles(df)
    df["orientation"] = df.apply(detect_orientation, axis=1)
    df["form_label"] = df.apply(label_form, axis=1)
    df = df.dropna(subset=["form_label"])
    return df

# %%
train_df = pd.read_csv("outputs/keypoints/train_keypoints.csv")
test_df = pd.read_csv("outputs/keypoints/test_keypoints.csv")

train_df = apply_labels(train_df)
test_df = apply_labels(test_df)

print(train_df.groupby(["label", "orientation", "form_label"]).size())
print(f"Null form_labels: {train_df['form_label'].isna().sum()}")

# %%
print("Labels per group for train split")
print(train_df.groupby(["label", "form_label"]).size())
print("Labels per group for test split")
print(test_df.groupby(["label", "form_label"]).size())

# %%
train_pct = train_df["label"].value_counts(normalize=True) * 100
test_pct = test_df["label"].value_counts(normalize=True)  * 100

comparison = pd.DataFrame({"train %": train_pct, "test %": test_pct}).round(1)
print(comparison)

# %% [markdown]
# As shown above, there is a relatively even distribution of exercise labels for the train/test splits. Almost all categories have a < 1% difference in distribution across splits, with the exception of pushups, which has a 2.4% difference. We considered this good enough to train on for our purposes. However, in the future, we may consider striving for a perfect distribution.

# %% [markdown]
# ### Visualisation of labelled data
# This function visualises the data by choosing n random frames for each class label, showing what it has labelled as the 'ground truth', as well as key feature values.

# %%
def visualize_labels(df, class_label, n=8):
    
    # Filter to only 'down' position frames per exercise
    if class_label == "squats":
        down = df[(df["label"] == class_label) & 
                  (df[["left_knee_angle", "right_knee_angle"]].min(axis=1) < 130)]
    elif class_label == "lunges":
        down = df[(df["label"] == class_label) & 
                  (df[["left_knee_angle", "right_knee_angle"]].min(axis=1) < 140)]
    elif class_label == "pushups":
        down = df[(df["label"] == class_label) & 
                  (df[["left_elbow_angle", "right_elbow_angle"]].min(axis=1) < 120)]
    elif class_label == "pullups":
        down = df[(df["label"] == class_label) & 
                  (df[["left_elbow_angle", "right_elbow_angle"]].min(axis=1) < 110)]
    else:
        down = df[df["label"] == class_label]

    good = down[down["form_label"] == "good"]
    bad  = down[down["form_label"] == "bad"]
    n_each = n // 2

    print(f"{class_label}: {len(good)} good down-position frames, {len(bad)} bad down-position frames")

    subset = pd.concat([
        good.sample(min(n_each, len(good)), random_state=42),
        bad.sample(min(n_each, len(bad)),   random_state=42)
    ]).reset_index(drop=True)

    cols = 4
    rows = max(1, len(subset) // cols)
    fig, axes = plt.subplots(rows, cols, figsize=(16, rows * 4))
    fig.suptitle(f"{class_label.upper()} — Down Position | Good (green) vs Bad (red)",
                 fontsize=14, fontweight="bold")
    axes = axes.flatten()

    for i, (_, row) in enumerate(subset.iterrows()):
        frame = cv2.imread(row["frame_path"])
        if frame is None:
            axes[i].set_visible(False)
            continue

        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        axes[i].imshow(frame)
        axes[i].axis("off")

        if class_label == "squats":
            info = (f"knee L={row['left_knee_angle']:.0f}°  R={row['right_knee_angle']:.0f}°\n"
                    f"torso={row['torso_angle']:.0f}°")
        elif class_label == "pushups":
            info = (f"elbow L={row['left_elbow_angle']:.0f}°  R={row['right_elbow_angle']:.0f}°\n"
                    f"body L={row['left_body_line']:.0f}°  head={row['head_drop']:.2f}")
        elif class_label == "lunges":
            info = (f"knee L={row['left_knee_angle']:.0f}°  R={row['right_knee_angle']:.0f}°\n"
                    f"torso={row['torso_angle']:.0f}°")
        elif class_label == "pullups":
            info = (f"elbow L={row['left_elbow_angle']:.0f}°  R={row['right_elbow_angle']:.0f}°\n"
                    f"shrug L={row['left_shoulder_shrug']:.2f}  R={row['right_shoulder_shrug']:.2f}")
        else:
            info = ""

        color = "green" if row["form_label"] == "good" else "red"
        axes[i].set_title(f"{row['form_label'].upper()}\n{info}",
                          fontsize=8, color=color, fontweight="bold")

    for j in range(i + 1, len(axes)):
        axes[j].set_visible(False)

    plt.tight_layout()
    plt.savefig(f"outputs/model/labels_{class_label}_down.png", dpi=120, bbox_inches="tight")
    plt.show()

# Check each class one by one
for label in train_df["label"].unique():
    visualize_labels(train_df, label, n=9)
    input(f"Press Enter to see next class...")  # pause between classes

# %% [markdown]
# # Training

# %% [markdown]
# #### As part of our project, we wanted to test out different models and architectures to find the most accurate one to use for our live-testing. Below are the models we will be testing:
# - MLP
# - ResNet-18 (CNN)
# - LSTM (RNN)
# - XGBoost
# - Transformer

# %%
# Load necessary packages
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import random
from torchvision import models, transforms
from PIL import Image
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from torch.utils.data import TensorDataset

# %% [markdown]
# Function to save best result from each model tested.

# %%
def save_model_artifacts(model_name, model, le, scaler, feature_cols, extra=None):
    os.makedirs(MODEL_DIR, exist_ok=True)

    # Save model
    if model_name in ("mlp", "lstm", "transformer", "resnet"):
        torch.save(model.state_dict(), f"{MODEL_DIR}/{model_name}_model.pth")
    else:
        with open(f"{MODEL_DIR}/{model_name}_model.pkl", "wb") as f:
            pickle.dump(model, f)

    # Save le
    with open(f"{MODEL_DIR}/{model_name}_le.pkl", "wb") as f:
        pickle.dump(le, f)

    # Save scaler (resnet uses image transforms, not a scaler)
    if scaler is not None:
        with open(f"{MODEL_DIR}/{model_name}_scaler.pkl", "wb") as f:
            pickle.dump(scaler, f)

    # Save metadata
    meta = {
        "feature_cols": feature_cols,
        "classes":      list(le.classes_),
        "num_classes":  len(le.classes_),
        "input_dim":    len(feature_cols) if feature_cols else None,
    }
    if extra:
        meta.update(extra)

    with open(f"{MODEL_DIR}/{model_name}_meta.json", "w") as f:
        json.dump(meta, f, indent=2)

    print(f"✓ {model_name} artifacts saved → {MODEL_DIR}/")

# %% [markdown]
# Function to print classification report and store results to make comparison plots at the end.

# %%
results = {}

def evaluate_and_store(model_name, y_true, y_pred, le, test_size):
    global results

    report = classification_report(y_true, y_pred,
                                   target_names=le.classes_,
                                   output_dict=True)

    results[model_name] = {
        "accuracy": report["accuracy"],
        "macro_f1": report["macro avg"]["f1-score"],
        "weighted_f1": report["weighted avg"]["f1-score"],
        "test_size": test_size,
        "per_class_f1": {cls: report[cls]["f1-score"] for cls in le.classes_}
    }

    print(f"\n── {model_name} Classification Report ──")
    print(classification_report(y_true, y_pred, target_names=le.classes_))

    # Confusion matrix for every model
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=le.classes_, yticklabels=le.classes_)
    plt.title(f"Confusion Matrix — {model_name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    
    safe_name = model_name.lower().replace(" ", "_").replace("(", "").replace(")", "")
    plt.savefig(f"{MODEL_DIR}/cm_{safe_name}.png", dpi=150, bbox_inches="tight")
    plt.show()

    return results[model_name]

# %% [markdown]
# ### MLP
# For our MLP model, we used 16 features that were used in our angle calculations to ensure model robustness and so that the model actually learned meaningful features.

# %%
MODEL_DIR = "outputs/model"
MODEL_PATH = "pose_landmarker.task"
os.makedirs(MODEL_DIR, exist_ok=True)

FEATURE_COLS = [
    "left_knee_angle", "right_knee_angle", "left_elbow_angle", "right_elbow_angle", "left_hip_angle",        
    "right_hip_angle", "left_body_line", "right_body_line", "left_shoulder_angle", "right_shoulder_angle",
    "torso_angle", "left_knee_bend", "right_knee_bend", "left_shoulder_shrug", 
    "right_shoulder_shrug", "head_drop"
]

# Feedback messages per predicted class
FEEDBACK = {
    "squats_good":  "Good squat form!",
    "squats_bad": "Fix squat: keep knees over toes, back straight",
    "pushups_good": "Good pushup form!",
    "pushups_bad": "Fix pushup: keep back flat, elbows at 45 degrees",
    "lunges_good": "Good lunge form!",
    "lunges_bad": "Fix lunge: front knee should not pass toes, torso should be facing forward",
    "pullups_good": "Good pullup form!",
    "pullups_bad": "Fix pullup: full range of motion, shoulders down"
}

def load_data_mlp(train_df, test_df):
    train_df = train_df.dropna(subset=["form_label"] + FEATURE_COLS)
    test_df = test_df.dropna(subset=["form_label"] + FEATURE_COLS)

    X_train = train_df[FEATURE_COLS].values.astype(np.float32)
    X_test = test_df[FEATURE_COLS].values.astype(np.float32)

    y_train_raw = (train_df["label"] + "_" + train_df["form_label"]).values
    y_test_raw = (test_df["label"]  + "_" + test_df["form_label"]).values

    le = LabelEncoder()
    le.fit(np.concatenate([y_train_raw, y_test_raw]))
    y_train = le.transform(y_train_raw)
    y_test = le.transform(y_test_raw)

    # Normalize features to same scale
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    print(f"Training samples : {len(X_train)}")
    print(f"Test samples     : {len(X_test)}")
    print(f"Classes          : {list(le.classes_)}")
    print(f"Feature count    : {X_train.shape[1]}\n")

    return X_train, X_test, y_train, y_test, le, scaler

# %%
X_train, X_test, y_train, y_test, le, scaler = load_data_mlp(train_df, test_df)

# %%
# Model 
class PoseDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class MLP(nn.Module):
    def __init__(self, input_dim, num_classes, dropout=0.4):
        super(MLP, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(dropout),
            
            nn.Linear(64, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(dropout),

            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        return self.net(x)

# %%
# Training
def train_model(X_train, y_train, X_test, y_test, le,
                epochs=50, batch_size=64, lr=1e-3):

    input_dim = X_train.shape[1]
    num_classes = len(le.classes_)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Training on: {device}\n")

    # Datasets & loaders
    train_loader = DataLoader(PoseDataset(X_train, y_train),
                              batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(PoseDataset(X_test,  y_test),
                              batch_size=batch_size, shuffle=False)

    model = MLP(input_dim, num_classes).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.5)

    history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

    for epoch in range(1, epochs + 1):
        model.train()
        total_loss, correct, total = 0.0, 0, 0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            logits = model(X_batch)
            loss = criterion(logits, y_batch)
            loss.backward()
            optimizer.step()

            total_loss += loss.item() * len(y_batch)
            correct += (logits.argmax(1) == y_batch).sum().item()
            total += len(y_batch)

        train_loss = total_loss / total
        train_acc = correct / total

        # Validate 
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for X_batch, y_batch in test_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                logits = model(X_batch)
                loss = criterion(logits, y_batch)
                val_loss += loss.item() * len(y_batch)
                val_correct += (logits.argmax(1) == y_batch).sum().item()
                val_total += len(y_batch)

        val_loss /= val_total
        val_acc = val_correct / val_total
        scheduler.step()

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)

        if epoch % 10 == 0 or epoch == 1:
            print(f"Epoch {epoch:3d}/{epochs} | "
                  f"Train Loss: {train_loss:.4f}  Acc: {train_acc:.4f} | "
                  f"Val Loss: {val_loss:.4f}  Acc: {val_acc:.4f}")

    return model, history, device

# %%
# Evaluation and plots
def evaluate_model(model, X_test, y_test, le, device):
    model.eval()
    X_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
    with torch.no_grad():
        preds = model(X_tensor).argmax(1).cpu().numpy()
    print("\n── Classification Report ──")
    print(classification_report(y_test, preds, target_names=le.classes_))
    evaluate_and_store("MLP (16 feat)", y_test, preds, le, len(y_test))
    
    return preds


def plot_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    ax1.plot(history["train_loss"], label="Train")
    ax1.plot(history["val_loss"], label="Val")
    ax1.set_title("Loss")
    ax1.set_xlabel("Epoch")
    ax1.legend()

    ax2.plot(history["train_acc"], label="Train")
    ax2.plot(history["val_acc"], label="Val")
    ax2.set_title("Accuracy")
    ax2.set_xlabel("Epoch")
    ax2.legend()

    plt.tight_layout()
    plt.savefig(f"{MODEL_DIR}/training_curves.png", dpi=150)
    plt.show()
    print(f"Saved → {MODEL_DIR}/training_curves.png")

# %%
model, history, device = train_model(X_train, y_train, X_test, y_test, le,
                                     epochs=50, batch_size=64, lr=1e-3)

plot_history(history)
evaluate_model(model, X_test, y_test, le, device)
save_model_artifacts("mlp", model, le, scaler, FEATURE_COLS)

# %% [markdown]
# ### ResNet-18 CNN

# %%
# Model
BATCH_SIZE = 32
EPOCHS = 20
LR = 1e-5
NUM_WORKERS = 4

# ImageNet normalization — required since we use pretrained ResNet
TRAIN_TRANSFORMS = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.2),
    transforms.RandomGrayscale(p=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

VAL_TRANSFORMS = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Include class weights in loss function
def get_class_weights(train_df, le):
    combined = (train_df["label"] + "_" + train_df["form_label"]).values
    encoded = le.transform(combined)
    counts = np.bincount(encoded)
    weights = 1.0 / counts
    weights = weights / weights.sum() * len(counts)  # normalize
    return torch.tensor(weights, dtype=torch.float).to(device)

class FrameDataset(Dataset):
    def __init__(self, df, label_encoder, transform):
        self.df = df.reset_index(drop=True)
        self.le = label_encoder
        self.transform = transform

        # Combined label: e.g. "squats_good", "pushups_bad"
        self.labels = self.le.transform(
            (df["label"] + "_" + df["form_label"]).values
        )

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        frame_path = self.df.loc[idx, "frame_path"]
        image = Image.open(frame_path).convert("RGB")
        image = self.transform(image)
        label = self.labels[idx]
        return image, label

def load_data_resnet(train_df, test_df):
    # Drop rows with missing labels
    train_df = train_df.dropna(subset=["frame_path", "label", "form_label"])
    test_df = test_df.dropna(subset=["frame_path", "label", "form_label"])

    # Fit label encoder on all combined labels
    all_labels = pd.concat([
        train_df["label"] + "_" + train_df["form_label"],
        test_df["label"] + "_" + test_df["form_label"]
    ]).values
    le = LabelEncoder()
    le.fit(all_labels)

    print(f"Classes     : {list(le.classes_)}")
    print(f"Train frames: {len(train_df)}")
    print(f"Test frames : {len(test_df)}\n")

    return train_df, test_df, le

# %%
def build_model(num_classes):
    model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
    # Freeze early layers — only fine-tune last 2 blocks + classifier
    for name, param in model.named_parameters():
        if "layer3" not in name and "layer4" not in name and "fc" not in name:
            param.requires_grad = False

    # Replace final FC layer to match our number of classes
    model.fc = nn.Sequential(
        nn.Dropout(0.4),
        nn.Linear(model.fc.in_features, num_classes)
    )
    return model
    
def train_model(train_df, test_df, le):
    num_classes = len(le.classes_)

    train_dataset = FrameDataset(train_df, le, TRAIN_TRANSFORMS)
    test_dataset = FrameDataset(test_df,  le, VAL_TRANSFORMS)

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              shuffle=True,  num_workers=NUM_WORKERS, pin_memory=True)
    test_loader = DataLoader(test_dataset,  batch_size=BATCH_SIZE,
                              shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

    model = build_model(num_classes).to(device)
    class_weights = get_class_weights(train_df, le)
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=LR, weight_decay=1e-2
    )
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode="max", patience=3, factor=0.5
)

    history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}
    best_val_acc = 0.0

    for epoch in range(1, EPOCHS + 1):
        # Train
        model.train()
        total_loss, correct, total = 0.0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            logits = model(images)
            loss   = criterion(logits, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item() * len(labels)
            correct += (logits.argmax(1) == labels).sum().item()
            total += len(labels)

        train_loss = total_loss / total
        train_acc = correct / total

        # Validate 
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device)
                logits = model(images)
                loss = criterion(logits, labels)
                val_loss += loss.item() * len(labels)
                val_correct += (logits.argmax(1) == labels).sum().item()
                val_total += len(labels)

        val_loss /= val_total
        val_acc = val_correct / val_total
        scheduler.step(val_acc)

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)

        print(f"Epoch {epoch:3d}/{EPOCHS} | "
              f"Train Loss: {train_loss:.4f}  Acc: {train_acc:.4f} | "
              f"Val Loss: {val_loss:.4f}  Acc: {val_acc:.4f}")

        # Save best model checkpoint
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), f"{MODEL_DIR}/cnn_best.pth")
            print(f"  ✓ New best model saved (val_acc={val_acc:.4f})")

    print(f"\nBest Val Accuracy: {best_val_acc:.4f}")
    return model, history

# %%
# Evaluation and plots
def evaluate_model(model, test_df, le):
    test_dataset = FrameDataset(test_df, le, VAL_TRANSFORMS)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE,
                              shuffle=False, num_workers=NUM_WORKERS)

    # Load best checkpoint for final evaluation
    model.load_state_dict(torch.load(f"{MODEL_DIR}/cnn_best.pth"))
    model.eval()

    all_preds, all_labels = [], []
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            preds = model(images).argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(labels.numpy())

    print("\n── Classification Report ──")
    print(classification_report(all_labels, all_preds, target_names=le.classes_))
    evaluate_and_store("ResNet18", all_labels, all_preds, le, len(all_labels))

def plot_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    ax1.plot(history["train_loss"], label="Train")
    ax1.plot(history["val_loss"], label="Val")
    ax1.set_title("Loss")
    ax1.set_xlabel("Epoch")
    ax1.legend()

    ax2.plot(history["train_acc"], label="Train")
    ax2.plot(history["val_acc"], label="Val")
    ax2.set_title("Accuracy")
    ax2.set_xlabel("Epoch")
    ax2.legend()

    plt.tight_layout()
    plt.savefig(f"{MODEL_DIR}/cnn_training_curves.png", dpi=150)
    plt.show()
    print(f"Saved → {MODEL_DIR}/cnn_training_curves.png")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_df, test_df, le = load_data_resnet(train_df, test_df)
model, history = train_model(train_df, test_df, le)
plot_history(history)
evaluate_model(model, test_df, le)
save_model_artifacts("resnet", model, le, None, [],
                     extra={"img_size": [224, 224], "architecture": "resnet18"})

# %% [markdown]
# ## LSTM on MLP model

# %%
SEQ_LEN = 10 
STRIDE = 3   

def build_sequences(df, feature_cols, seq_len=SEQ_LEN, stride=STRIDE):
    sequences, labels = [], []
    
    for video_name, group in df.groupby("video_name"):
        group = group.sort_values("frame_index").reset_index(drop=True)
        if len(group) < seq_len:
            continue
        
        # Smaller stride = many more sequences per video
        for start in range(0, len(group) - seq_len + 1, stride):
            window = group.iloc[start:start + seq_len]
            
            # Majority vote on label instead of requiring all same
            label = window["form_label"].mode()[0]
            exercise = window["label"].iloc[0] 
            seq = window[feature_cols].values
            sequences.append(seq)
            labels.append(f"{exercise}_{label}")
    
    return np.array(sequences), np.array(labels)

# %%
class PoseLSTM(nn.Module):
    def __init__(self, input_dim, num_classes, hidden_dim=128, num_layers=2, dropout=0.3):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout,
            bidirectional=True        
        )
        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim * 2, 64), # *2 for bidirectional
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        out, (hn, _) = self.lstm(x)
        # Concatenate final hidden state from both directions
        fwd = hn[-2] # last layer, forward
        bwd = hn[-1] # last layer, backward
        return self.classifier(torch.cat([fwd, bwd], dim=1))

# %%
def train_lstm(train_df, test_df, feature_cols, epochs=50, batch_size=32, lr=1e-3):
    X_train, y_train_raw = build_sequences(train_df, feature_cols)
    X_test, y_test_raw = build_sequences(test_df, feature_cols)
    
    print(f"Train sequences: {len(X_train)}")
    print(f"Test sequences:  {len(X_test)}")

    le = LabelEncoder()
    le.fit(np.concatenate([y_train_raw, y_test_raw]))
    y_train = le.transform(y_train_raw)
    y_test = le.transform(y_test_raw)

    # Normalize per feature across all frames
    X_flat = X_train.reshape(-1, X_train.shape[-1])
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_flat).reshape(X_train.shape)
    X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

    train_ds = torch.utils.data.TensorDataset(
        torch.tensor(X_train, dtype=torch.float32),
        torch.tensor(y_train, dtype=torch.long)
    )
    test_ds = torch.utils.data.TensorDataset(
        torch.tensor(X_test, dtype=torch.float32),
        torch.tensor(y_test, dtype=torch.long)
    )

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False)

    model = PoseLSTM(input_dim=len(feature_cols), num_classes=len(le.classes_)).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", patience=5, factor=0.5
    )

    best_val_acc = 0.0
    for epoch in range(1, epochs + 1):
        model.train()
        total_loss, correct, total = 0.0, 0, 0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            logits = model(X_batch)
            loss   = criterion(logits, y_batch)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # prevent exploding gradients
            optimizer.step()
            total_loss += loss.item() * len(y_batch)
            correct += (logits.argmax(1) == y_batch).sum().item()
            total += len(y_batch)

        model.eval()
        val_correct, val_total = 0, 0
        with torch.no_grad():
            for X_batch, y_batch in test_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                preds = model(X_batch).argmax(1)
                val_correct += (preds == y_batch).sum().item()
                val_total += len(y_batch)

        val_acc = val_correct / val_total
        scheduler.step(val_acc)

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), "outputs/model/lstm_best.pth")

        if epoch % 10 == 0:
            print(f"Epoch {epoch:3d}/{epochs} | "
                  f"Loss: {total_loss/total:.4f} | "
                  f"Val Acc: {val_acc:.4f}")

    print(f"\nBest Val Accuracy: {best_val_acc:.4f}")

    # Load best checkpoint for final evaluation
    model.load_state_dict(torch.load("outputs/model/lstm_best.pth"))
    model.eval()

    all_preds, all_labels = [], []
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch = X_batch.to(device)
            preds   = model(X_batch).argmax(1).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(y_batch.numpy())

    evaluate_and_store("LSTM", all_labels, all_preds, le, len(all_labels))
    
    return model, le, scaler

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
lstm_model, le_seq, scaler_seq = train_lstm(
    train_df, test_df,
    feature_cols=FEATURE_COLS,
    epochs=50,
    batch_size=32,
    lr=1e-3
)
save_model_artifacts("lstm", lstm_model, le_seq, scaler_seq, FEATURE_COLS,
                     extra={"seq_len": SEQ_LEN})

# %% [markdown]
# ## XGBoost

# %%
X_train, X_test, y_train, y_test, le, scaler = load_data_mlp(train_df, test_df)

xgb = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    use_label_encoder=False,
    eval_metric="mlogloss",
    random_state=42,
    n_jobs=-1
)

xgb.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=50 # print every 50 rounds
)

y_pred = xgb.predict(X_test)
evaluate_and_store("XGBoost", y_test, y_pred, le, len(y_test))
save_model_artifacts("xgb", xgb, le, scaler, FEATURE_COLS)

# Show feature importance
importances = xgb.feature_importances_
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10, 5))
plt.bar(range(len(FEATURE_COLS)), importances[indices])
plt.xticks(range(len(FEATURE_COLS)), [FEATURE_COLS[i] for i in indices], rotation=45, ha="right")
plt.title("XGBoost Feature Importances")
plt.tight_layout()
plt.savefig("outputs/model/xgb_feature_importance.png", dpi=150)
plt.show()

# %% [markdown]
# ## Transformer

# %%
# Model
class PoseTransformer(nn.Module):
    def __init__(self, input_dim, num_classes, num_heads=4, num_layers=2, dropout=0.3):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, 64)
        self.pos_encoding = nn.Parameter(torch.randn(1, 100, 64))  # learnable positional encoding
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=64, nhead=num_heads, dropout=dropout,
            dim_feedforward=256, batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.classifier = nn.Sequential(
            nn.Linear(64, 32),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(32, num_classes)
        )

    def forward(self, x):
        x = self.input_proj(x)                        # (batch, seq, 64)
        x = x + self.pos_encoding[:, :x.size(1), :]   # add positional encoding
        x = self.transformer(x)                       # (batch, seq, 64)
        x = x.mean(dim=1)                             # global average pool
        return self.classifier(x)


# Build sequences
SEQ_LEN = 20
STRIDE = 5

X_train_seq, y_train_raw = build_sequences(train_df, FEATURE_COLS, seq_len=SEQ_LEN, stride=STRIDE)
X_test_seq, y_test_raw = build_sequences(test_df, FEATURE_COLS, seq_len=SEQ_LEN, stride=STRIDE)

print(f"Train sequences: {len(X_train_seq)}")
print(f"Test sequences:  {len(X_test_seq)}")

# Normalise
X_flat = X_train_seq.reshape(-1, X_train_seq.shape[-1])
scaler_seq = StandardScaler()
X_train_seq = scaler_seq.fit_transform(X_flat).reshape(X_train_seq.shape)
X_test_seq = scaler_seq.transform(
    X_test_seq.reshape(-1, X_test_seq.shape[-1])
).reshape(X_test_seq.shape)

# Encode labels
le_seq = LabelEncoder()
le_seq.fit(np.concatenate([y_train_raw, y_test_raw]))
y_train_enc = le_seq.transform(y_train_raw)
y_test_enc = le_seq.transform(y_test_raw)

# Dataloaders
train_ds = TensorDataset(
    torch.tensor(X_train_seq, dtype=torch.float32),
    torch.tensor(y_train_enc, dtype=torch.long)
)
test_ds = TensorDataset(
    torch.tensor(X_test_seq, dtype=torch.float32),
    torch.tensor(y_test_enc, dtype=torch.long)
)
train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
test_loader = DataLoader(test_ds,  batch_size=32, shuffle=False)

# %%
# Train
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_tr = PoseTransformer(input_dim=len(FEATURE_COLS), num_classes=len(le_seq.classes_)).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_tr.parameters(), lr=1e-3, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode="max", patience=5, factor=0.5
)

best_val_acc = 0.0
EPOCHS = 50

for epoch in range(1, EPOCHS + 1):
    model_tr.train()
    total_loss, correct, total = 0.0, 0, 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        logits = model_tr(X_batch)
        loss = criterion(logits, y_batch)
        loss.backward()
        nn.utils.clip_grad_norm_(model_tr.parameters(), max_norm=1.0)
        optimizer.step()
        total_loss += loss.item() * len(y_batch)
        correct += (logits.argmax(1) == y_batch).sum().item()
        total += len(y_batch)

    model_tr.eval()
    val_correct, val_total = 0, 0
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            preds = model_tr(X_batch).argmax(1)
            val_correct += (preds == y_batch).sum().item()
            val_total += len(y_batch)

    val_acc = val_correct / val_total
    scheduler.step(val_acc)

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model_tr.state_dict(), "outputs/model/transformer_best.pth")

    if epoch % 10 == 0:
        print(f"Epoch {epoch:3d}/{EPOCHS} | "
              f"Loss: {total_loss/total:.4f} | "
              f"Val Acc: {val_acc:.4f}")

print(f"\nBest Val Accuracy: {best_val_acc:.4f}")

# %%
# Evaluation
model_tr.load_state_dict(torch.load("outputs/model/transformer_best.pth"))
model_tr.eval()

all_preds, all_labels = [], []
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch = X_batch.to(device)
        preds   = model_tr(X_batch).argmax(1).cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(y_batch.numpy())

evaluate_and_store("Transformer", all_labels, all_preds, le_seq, len(all_labels))
save_model_artifacts("transformer", model_tr, le_seq, scaler_seq, FEATURE_COLS,
                     extra={"seq_len": SEQ_LEN})

# %% [markdown]
# ### Comparison plot of models

# %%
def plot_model_comparisons(results):
    model_names  = list(results.keys())
    accuracies = [r["accuracy"] for r in results.values()]
    macro_f1s = [r["macro_f1"] for r in results.values()]
    weighted_f1s = [r["weighted_f1"] for r in results.values()]
    colors = ["#d9534f", "#f0ad4e", "#5bc0de", "#5cb85c", "#337ab7", "#9b59b6"]

    classes = ["lunges_bad", "lunges_good", "pullups_bad", "pullups_good",
               "pushups_bad", "pushups_good", "squats_bad", "squats_good"]

    # 1. Accuracy vs Macro F1 grouped bar
    fig, ax = plt.subplots(figsize=(12, 6))
    fig.patch.set_facecolor("#f8f9fa")
    ax.set_facecolor("#f8f9fa")
    x = np.arange(len(model_names))
    width = 0.35
    bars1 = ax.bar(x - width/2, accuracies, width, label="Accuracy",
                   color=colors, alpha=0.9, edgecolor="white")
    bars2 = ax.bar(x + width/2, macro_f1s,  width, label="Macro F1",
                   color=colors, alpha=0.5, edgecolor="white")
    ax.set_xticks(x)
    ax.set_xticklabels(model_names, fontsize=11)
    ax.set_ylim(0, 1.05)
    ax.set_title("Accuracy vs Macro F1 by Model", fontsize=14, fontweight="bold", pad=15)
    ax.grid(axis="y", alpha=0.3)
    ax.legend(fontsize=10)
    ax.axhline(0.5, color="gray", linestyle="--", linewidth=1, alpha=0.4, label="Chance")
    for bar, val in zip(bars1, accuracies):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
                f"{val:.0%}", ha="center", fontsize=9, fontweight="bold")
    for bar, val in zip(bars2, macro_f1s):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
                f"{val:.0%}", ha="center", fontsize=9, fontweight="bold")
    plt.tight_layout()
    plt.savefig(f"{MODEL_DIR}/plot1_accuracy_vs_f1.png", dpi=150, bbox_inches="tight", facecolor="#f8f9fa")
    plt.show()
    print("Plot 1/4 saved → plot1_accuracy_vs_f1.png\n")

    # 2. Accuracy progression line
    fig, ax = plt.subplots(figsize=(12, 6))
    fig.patch.set_facecolor("#f8f9fa")
    ax.set_facecolor("#f8f9fa")
    ax.plot(model_names, accuracies, "o-", color="#337ab7", linewidth=2.5,
            markersize=12, markerfacecolor="white", markeredgewidth=2.5, zorder=5)
    for i, (name, acc) in enumerate(zip(model_names, accuracies)):
        ax.annotate(f"{acc:.0%}", (i, acc),
                    textcoords="offset points", xytext=(0, 14),
                    ha="center", fontsize=11, fontweight="bold", color="#337ab7")
    ax.set_xticks(range(len(model_names)))
    ax.set_xticklabels(model_names, fontsize=11)
    ax.set_ylim(0.3, 0.95)
    ax.set_ylabel("Accuracy", fontsize=12)
    ax.set_title("Accuracy Progression Across Models", fontsize=14, fontweight="bold", pad=15)
    ax.grid(alpha=0.3)
    ax.axhline(0.5, color="gray", linestyle="--", linewidth=1, alpha=0.4, label="Chance baseline")
    ax.fill_between(range(len(model_names)), accuracies, 0.3, alpha=0.08, color="#337ab7")
    ax.legend(fontsize=10)
    plt.tight_layout()
    plt.savefig(f"{MODEL_DIR}/plot2_accuracy_progression.png", dpi=150, bbox_inches="tight", facecolor="#f8f9fa")
    plt.show()
    print("Plot 2/4 saved → plot2_accuracy_progression.png\n")

    # 3. Per-class F1 heatmap
    fig, ax = plt.subplots(figsize=(14, 6))
    fig.patch.set_facecolor("#f8f9fa")
    f1_matrix = np.array([
        [results[m]["per_class_f1"].get(c, 0) for c in classes]
        for m in model_names
    ])
    im = ax.imshow(f1_matrix, cmap="RdYlGn", aspect="auto", vmin=0, vmax=1)
    ax.set_xticks(range(len(classes)))
    ax.set_xticklabels([c.replace("_", "\n") for c in classes], fontsize=11)
    ax.set_yticks(range(len(model_names)))
    ax.set_yticklabels(model_names, fontsize=11)
    ax.set_title("Per-Class F1 Score Heatmap", fontsize=14, fontweight="bold", pad=15)
    plt.colorbar(im, ax=ax, label="F1 Score")
    for i in range(len(model_names)):
        for j in range(len(classes)):
            val = f1_matrix[i, j]
            ax.text(j, i, f"{val:.2f}", ha="center", va="center",
                    fontsize=10, fontweight="bold",
                    color="white" if val < 0.35 or val > 0.75 else "black")
    plt.tight_layout()
    plt.savefig(f"{MODEL_DIR}/plot3_f1_heatmap.png", dpi=150, bbox_inches="tight", facecolor="#f8f9fa")
    plt.show()
    print("Plot 3/4 saved → plot3_f1_heatmap.png\n")

    # 4. Per-class F1 grouped bar
    fig, ax = plt.subplots(figsize=(16, 7))
    fig.patch.set_facecolor("#f8f9fa")
    ax.set_facecolor("#f8f9fa")
    x_cls = np.arange(len(classes))
    n = len(model_names)
    width = 0.13
    for i, model_name in enumerate(model_names):
        f1_vals = [results[model_name]["per_class_f1"].get(c, 0) for c in classes]
        offset = (i - n/2 + 0.5) * width
        ax.bar(x_cls + offset, f1_vals, width, label=model_name,
               color=colors[i], alpha=0.85, edgecolor="white")
    ax.set_xticks(x_cls)
    ax.set_xticklabels([c.replace("_", "\n") for c in classes], fontsize=11)
    ax.set_ylim(0, 1.05)
    ax.set_ylabel("F1 Score", fontsize=12)
    ax.set_title("Per-Class F1 Score by Model", fontsize=14, fontweight="bold", pad=15)
    ax.legend(loc="lower right", fontsize=9)
    ax.grid(axis="y", alpha=0.3)
    ax.axhline(0.7, color="gray", linestyle="--", linewidth=1, alpha=0.4, label="0.7 threshold")
    plt.tight_layout()
    plt.savefig(f"{MODEL_DIR}/plot4_per_class_f1.png", dpi=150, bbox_inches="tight", facecolor="#f8f9fa")
    plt.show()
    print("Plot 4/4 saved → plot4_per_class_f1.png\n")

    print("All plots saved to", MODEL_DIR)

# %%
plot_model_comparisons(results)

# %% [markdown]
# # Live Test

# %% [markdown]
# #### Download the following files from /outputs/model:
# - xgb_le.pkl
# - xgb_model.pkl
# - xgb_scaler.pkl
#
# #### Download and run the livecam.py script to test the XGBoost model.
