# %%
# Import packages
import os
import cv2
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python.vision import PoseLandmarker, PoseLandmarkerOptions
from mediapipe.tasks.python import BaseOptions
import pandas as pd
from tqdm import tqdm
import urllib.request
import numpy as np
# Out:
# 2026-02-25 08:53:42.870324: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-25 08:53:42.870396: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-25 08:53:42.872176: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-02-25 08:53:42.882153: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Configure directories
UCF_VIDEOS = "UCF-101"
UCF_SPLITS = "UCF101TrainTestSplits/ucfTrainTestlist"
FRAMES_DIR = "outputs/frames"
KEYPOINTS_DIR = "outputs/keypoints"

# Convert UCF101 classes to our labels
EXERCISE_CLASSES = {
    "PushUps": "pushups", 
    "BodyWeightSquats": "squats",
    "Lunges": "lunges",
    "PullUps": "pullups",
    "JumpingJack": "jumping_jacks"
}

# Configure desired frame rates and image size
TARGET_FPS = 10
IMG_SIZE = (640, 480)

# %%
# Filter 5 classes from train/test 01
# We are just using one train/test split for this project

def load_videos():
    rows = []
    for split, filename in [("train", "trainlist01.txt"), ("test", "testlist01.txt")]:
        filepath = os.path.join(UCF_SPLITS, filename)
        with open(filepath) as f:
            for line in f: # e.g. BodyWeightSquats/v_BodyWeightSquats_g08_c01.avi
                rel_path = line.strip().split()[0]
                class_name = rel_path.split("/")[0]
                if class_name not in EXERCISE_CLASSES:
                    continue
                rows.append({
                    "video_path": os.path.join(UCF_VIDEOS, rel_path),
                    "label": EXERCISE_CLASSES[class_name],
                    "split": split,
                    "video_name": os.path.splitext(os.path.basename(rel_path))[0]
                })
    df = pd.DataFrame(rows)
    print(f"Found {len(df)} exercise videos\n{df['label'].value_counts()}\n")
    return df

# %%
# Extract frames from the videos
def extract_frames(video_df):
    rows = []
    for _, row in tqdm(video_df.iterrows(), total=len(video_df), desc="Extracting keyframes"):
        save_dir = os.path.join(FRAMES_DIR, row["split"], row["label"], row["video_name"])
        os.makedirs(save_dir, exist_ok=True)

        # Use OpenCV to open the .avi file
        # Checks the video's native FPS and determines how many frames to get based on that
        cap = cv2.VideoCapture(row["video_path"])
        fps = cap.get(cv2.CAP_PROP_FPS) or TARGET_FPS
        frame_interval = max(1, int(round(fps / TARGET_FPS)))

        frame_idx = 0 # Tracks every frame seens
        saved_idx = 0 # Tracks only the frames to save

        while True:
            ret, frame = cap.read()
            if not ret:
                break # Ret = False once the video has ended, so break
            if frame_idx % frame_interval == 0: # Resize and save frames in wanted interval
                frame_path = os.path.join(save_dir, f"frame_{saved_idx:04d}.jpg")
                cv2.imwrite(frame_path, cv2.resize(frame, IMG_SIZE))
                rows.append({**row, "frame_path": frame_path, "frame_index": saved_idx})
                saved_idx += 1
            frame_idx += 1
        cap.release() # Closes the video
    df = pd.DataFrame(rows)
    print(f"Extracted {len(df)} frames total\n")
    return df

# %%
# Name keypoints according to MediaPipe Pose standards
KEYPOINT_NAMES = [
    "nose", "left_eye_inner", "left_eye", "left_eye_outer",
    "right_eye_inner", "right_eye", "right_eye_outer",
    "left_ear", "right_ear", "mouth_left", "mouth_right",
    "left_shoulder", "right_shoulder", "left_elbow", "right_elbow",
    "left_wrist", "right_wrist", "left_pinky", "right_pinky",
    "left_index", "right_index", "left_thumb", "right_thumb",
    "left_hip", "right_hip", "left_knee", "right_knee",
    "left_ankle", "right_ankle", "left_heel", "right_heel",
    "left_foot_index", "right_foot_index",
]

# Download the MediaPipe Pose model
MODEL_PATH = "pose_landmarker.task"
if not os.path.exists(MODEL_PATH):
    print("Downloading pose model...")
    urllib.request.urlretrieve(
        "https://storage.googleapis.com/mediapipe-models/pose_landmarker/pose_landmarker_full/float16/latest/pose_landmarker_full.task",
        MODEL_PATH
    )
    print("Downloaded!")

# Extract keypoints 
def extract_keypoints(frame_df):
    os.makedirs(KEYPOINTS_DIR, exist_ok=True)
    options = PoseLandmarkerOptions(
        base_options=BaseOptions(model_asset_path=MODEL_PATH),
        running_mode=mp.tasks.vision.RunningMode.IMAGE,
        num_poses=1,
        min_pose_detection_confidence=0.5,
    )
    rows = []
    with PoseLandmarker.create_from_options(options) as landmarker:
        # Loop through each frame in the dataframe
        for _, row in tqdm(frame_df.iterrows(), total=len(frame_df), desc="Pose estimation"):
            frame = cv2.imread(row["frame_path"])
            if frame is None:
                continue
            
            # Run MediaPipe on the frame after converting to RGB
            rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb)
            results = landmarker.detect(mp_image)
            if not results.pose_landmarks:
                continue

            landmarks = results.pose_landmarks[0]
            keypoints = {}
            for i, name in enumerate(KEYPOINT_NAMES):
                kp = landmarks[i]
                # x and y-> position on screen
                keypoints[f"{name}_x"]   = round(kp.x, 6)
                keypoints[f"{name}_y"]   = round(kp.y, 6)

            rows.append({
                "frame_path": row["frame_path"],
                "video_name": row["video_name"],
                "label": row["label"],
                "split": row["split"],
                "frame_index": row["frame_index"],
                **keypoints # Append entire keyframes dictionary at once
            })

    df = pd.DataFrame(rows)
    # Output two CSVs that the model will train on (train and test keypoints)
    for split, group in df.groupby("split"):
        out_path = os.path.join(KEYPOINTS_DIR, f"{split}_keypoints.csv")
        group.to_csv(out_path, index=False)
        print(f"Saved {len(group)} rows → {out_path}")
        print(group["label"].value_counts(), "\n")
    return df

# %%
video_df = load_videos()
frame_df = extract_frames(video_df)
extract_keypoints(frame_df)
# Out:
# Found 564 exercise videos
# label
# lunges           127
# jumping_jacks    123
# squats           112
# pushups          102
# pullups          100
# Name: count, dtype: int64
# Extracting keyframes: 100%|██████████| 564/564 [01:44<00:00,  5.39it/s]
# Extracted 34043 frames total
# Pose estimation: 100%|██████████| 34043/34043 [35:32<00:00, 15.96it/s]
# Saved 7652 rows → outputs/keypoints\test_keypoints.csv
# label
# lunges           2952
# squats           1812
# pushups           980
# jumping_jacks     971
# pullups           937
# Name: count, dtype: int64
#
# Saved 21289 rows → outputs/keypoints\train_keypoints.csv
# label
# lunges           8564
# squats           5312
# pullups          2819
# pushups          2311
# jumping_jacks    2283
# Name: count, dtype: int64
#                                               frame_path  \
# 0      outputs/frames\train\squats\v_BodyWeightSquats...
# 1      outputs/frames\train\squats\v_BodyWeightSquats...
# 2      outputs/frames\train\squats\v_BodyWeightSquats...
# 3      outputs/frames\train\squats\v_BodyWeightSquats...
# 4      outputs/frames\train\squats\v_BodyWeightSquats...
# ...                                                  ...
# 28936  outputs/frames\test\pushups\v_PushUps_g07_c04\...
# 28937  outputs/frames\test\pushups\v_PushUps_g07_c04\...
# 28938  outputs/frames\test\pushups\v_PushUps_g07_c04\...
# 28939  outputs/frames\test\pushups\v_PushUps_g07_c04\...
# 28940  outputs/frames\test\pushups\v_PushUps_g07_c04\...
#
#                        video_name    label  split  frame_index    nose_x  \
# 0      v_BodyWeightSquats_g08_c01   squats  train            0  0.498673
# 1      v_BodyWeightSquats_g08_c01   squats  train            1  0.500554
# 2      v_BodyWeightSquats_g08_c01   squats  train            2  0.499823
# 3      v_BodyWeightSquats_g08_c01   squats  train            3  0.498956
# 4      v_BodyWeightSquats_g08_c01   squats  train            4  0.502800
# ...                           ...      ...    ...          ...       ...
# 28936           v_PushUps_g07_c04  pushups   test           33  0.491798
# 28937           v_PushUps_g07_c04  pushups   test           34  0.459866
# 28938           v_PushUps_g07_c04  pushups   test           36  0.485839
# 28939           v_PushUps_g07_c04  pushups   test           37  0.474144
# 28940           v_PushUps_g07_c04  pushups   test           38  0.472573
#
#          nose_y  left_eye_inner_x  left_eye_inner_y  left_eye_x  ...  \
# 0      0.326496          0.498823          0.310232    0.500799  ...
# 1      0.326976          0.500588          0.310929    0.502863  ...
# 2      0.333185          0.499327          0.315805    0.501402  ...
# 3      0.325757          0.499174          0.310002    0.501396  ...
# 4      0.319947          0.501783          0.304821    0.503626  ...
# ...         ...               ...               ...         ...  ...
# 28936  0.741182          0.504473          0.722548    0.511692  ...
# 28937  0.624580          0.474851          0.611060    0.480182  ...
# 28938  0.422360          0.497983          0.404252    0.503457  ...
# 28939  0.419561          0.489614          0.402014    0.495636  ...
# 28940  0.432696          0.485061          0.418085    0.492898  ...
#
#        right_ankle_x  right_ankle_y  left_heel_x  left_heel_y  right_heel_x  \
# 0           0.418064       0.926531     0.502136     0.951608      0.416589
# 1           0.416381       0.922342     0.515106     0.950867      0.417111
# 2           0.418781       0.929287     0.501734     0.939595      0.416618
# 3           0.416944       0.929216     0.502690     0.939821      0.408781
# 4           0.414609       0.930650     0.514345     0.958497      0.416563
# ...              ...            ...          ...          ...           ...
# 28936       0.463961       0.596942     0.560517     0.595279      0.465687
# 28937       0.450235       0.766787     0.518398     0.703976      0.450736
# 28938       0.421034       0.497498     0.525097     0.510711      0.430590
# 28939       0.405623       0.473469     0.535121     0.495098      0.414505
# 28940       0.387196       0.481651     0.500051     0.515267      0.394728
#
#        right_heel_y  left_foot_index_x  left_foot_index_y  right_foot_index_x  \
# 0          0.943314           0.521340           0.987345            0.437218
# 1          0.942610           0.539033           0.987205            0.431652
# 2          0.949759           0.534167           0.994335            0.434127
# 3          0.947273           0.539880           0.989181            0.434386
# 4          0.932616           0.542549           0.990175            0.433984
# ...             ...                ...                ...                 ...
# 28936      0.575658           0.560055           0.663198            0.476345
# 28937      0.755018           0.536200           0.724278            0.461990
# 28938      0.484257           0.556674           0.577655            0.427744
# 28939      0.468439           0.567136           0.551393            0.405220
# 28940      0.478962           0.531268           0.572963            0.385700
#
#        right_foot_index_y
# 0                0.987540
# 1                0.986853
# 2                0.993849
# 3                0.992563
# 4                0.993992
# ...                   ...
# 28936            0.633492
# 28937            0.794594
# 28938            0.554614
# 28939            0.512244
# 28940            0.519669
#
# [28941 rows x 71 columns]

# %%
# Delete unnecessary keypoints so file size can be saved to GitHub
useful_keypoints = [
    "left_shoulder", "right_shoulder", "left_elbow", "right_elbow",
    "left_wrist", "right_wrist", "left_hip", "right_hip",
    "left_knee", "right_knee", "left_ankle", "right_ankle", 
    "nose", "left_ear", "right_ear"
]

train_df = pd.read_csv("outputs/keypoints/train_keypoints.csv")
keep_cols = ["frame_path", "video_name", "label", "split", "frame_index"]
for kp in useful_keypoints:
    keep_cols += [f"{kp}_x", f"{kp}_y"]

train_df = train_df[keep_cols]
train_df.to_csv("outputs/keypoints/train_keypoints.csv", index=False)

test_df = pd.read_csv("outputs/keypoints/test_keypoints.csv")
keep_cols = ["frame_path", "video_name", "label", "split", "frame_index"]
for kp in useful_keypoints:
    keep_cols += [f"{kp}_x", f"{kp}_y"]

test_df = test_df[keep_cols]
test_df.to_csv("outputs/keypoints/test_keypoints.csv", index=False)

# %% [markdown]
# ## Feature Computation and Labeling

# %%
def compute_angle(a, b, c):
    """Angle at point b, formed by a-b-c"""
    a, b, c = np.array(a), np.array(b), np.array(c)
    ba = a - b
    bc = c - b
    cos_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc) + 1e-8)
    return np.degrees(np.arccos(np.clip(cos_angle, -1.0, 1.0)))

def add_angles(df):
    def angle(r, a, b, c):
        """Helper to pull x/y from row and compute angle at b"""
        return compute_angle(
            (r[f"{a}_x"], r[f"{a}_y"]),
            (r[f"{b}_x"], r[f"{b}_y"]),
            (r[f"{c}_x"], r[f"{c}_y"])
        )

    # KNEE ANGLES (squats, lunges) 
    for side in ["left", "right"]:
        df[f"{side}_knee_angle"] = df.apply(
            lambda r, s=side: angle(r, f"{s}_hip", f"{s}_knee", f"{s}_ankle"), axis=1)

    # ELBOW ANGLES (push-ups, pull-ups)
    for side in ["left", "right"]:
        df[f"{side}_elbow_angle"] = df.apply(
            lambda r, s=side: angle(r, f"{s}_shoulder", f"{s}_elbow", f"{s}_wrist"), axis=1)

    # HIP ANGLES (squats, lunges, pull-ups)
    for side in ["left", "right"]:
        df[f"{side}_hip_angle"] = df.apply(
            lambda r, s=side: angle(r, f"{s}_shoulder", f"{s}_hip", f"{s}_knee"), axis=1)

    # BODY LINE / HIP SAG (push-ups)
    for side in ["left", "right"]:
        df[f"{side}_body_line"] = df.apply(
            lambda r, s=side: angle(r, f"{s}_shoulder", f"{s}_hip", f"{s}_ankle"), axis=1)

    # TORSO UPRIGHTNESS (lunges, squats)
    # Angle between vertical and the shoulder-hip vector
    df["torso_angle"] = df.apply(lambda r: compute_angle(
        (r["left_shoulder_x"], r["left_shoulder_y"] - 0.1),  # point above shoulder
        (r["left_shoulder_x"], r["left_shoulder_y"]),
        (r["left_hip_x"],      r["left_hip_y"])
    ), axis=1)

    # KNEE BEND (squats, lunges)
    # How far knee is inside/outside the ankle - not an angle, just a distance
    for side in ["left", "right"]:
        df[f"{side}_knee_bend"] = df[f"{side}_knee_x"] - df[f"{side}_ankle_x"]

    # HEAD DROP (push-ups) 
    df["head_drop"] = df["nose_y"] - df["left_shoulder_y"]

    # SHOULDER SHRUG (pull-ups)
    for side in ["left", "right"]:
        df[f"{side}_shoulder_shrug"] = df[f"{side}_ear_y"] - df[f"{side}_shoulder_y"]

    # SHOULDER ANGLE (pull-ups)
    for side in ["left", "right"]:
        df[f"{side}_shoulder_angle"] = df.apply(
        lambda r, s=side: angle(r, f"{s}_elbow", f"{s}_shoulder", f"{s}_hip"), axis=1)

    # SYMMETRY (jumping jacks)
    df["arm_symmetry"] = abs(df["left_elbow_angle"] - df["right_elbow_angle"])
    df["leg_symmetry"] = abs(df["left_knee_angle"]  - df["right_knee_angle"])
    df["hip_symmetry"] = abs(df["left_hip_angle"]   - df["right_hip_angle"])

    return df

# %%
FORM_RULES = {
    "squats": lambda r: (
        min(r["left_knee_angle"], r["right_knee_angle"]) < 160 and
        abs(r["left_knee_bend"]) < 0.05 and
        abs(r["right_knee_bend"]) < 0.05 and
        r["torso_angle"] > 150
    ),
    "pushups": lambda r: (
        abs(r["left_body_line"] - 180) < 35 and
        abs(r["right_body_line"] - 180) < 35 and
        r["head_drop"] < 0.10
    ),
    "lunges": lambda r: (
        r["torso_angle"] > 160 and  # Torso upright
        abs(r["left_knee_bend"]) < 0.03 and
        abs(r["right_knee_bend"]) < 0.03 
    ),
    "pullups": lambda r: (
        r["arm_symmetry"] < 20 and
        r["left_shoulder_shrug"] < -0.03 and   # Shoulders not shrugged
        r["right_shoulder_shrug"] < -0.03
    ),
    "jumping_jacks": lambda r: (
        r["arm_symmetry"] < 10 and
        r["leg_symmetry"] < 10
    ),
}

#label by frame
def label_form(df):
    def apply_rule(row):
        rule = FORM_RULES.get(row["label"])
        if rule is None:
            return None
        try:
            return "good" if rule(row) else "bad"
        except:
            return None
    df["form_label"] = df.apply(apply_rule, axis=1)
    return df

# %%
#goal: find most representative frame -- lowest squat, etc.

def label_form_by_video(df):
    def assess_video(group):
        label = group["label"].iloc[0]
        rule = FORM_RULES.get(label)
        if rule is None:
            return group

        if label in ("squats", "lunges"):
            representative = group.loc[
                group[["left_knee_angle", "right_knee_angle"]].min(axis=1).idxmin()
            ]
        elif label in ("pushups", "pullups"):
            representative = group.loc[
                group[["left_elbow_angle", "right_elbow_angle"]].min(axis=1).idxmin()
            ]
        else:
            representative = group.loc[group["arm_symmetry"].idxmin()]

        try:
            form = "good" if rule(representative) else "bad"
        except:
            form = None

        group["form_label"] = form
        return group

    return df.groupby("video_name", group_keys=False).apply(assess_video, include_groups=False)

# %%
#percentage of frame good --> video is good
def label_form_by_video(df):
    def assess_video(group):
        label = group["label"].iloc[0]
        rule = FORM_RULES.get(label)
        if rule is None:
            return group

        try:
            good_frame_pct = group.apply(rule, axis=1).mean()
            form = "good" if good_frame_pct >= 0.30 else "bad"
        except:
            form = None

        group["form_label"] = form
        return group

    return df.groupby("video_name", group_keys=False).apply(assess_video, include_groups=False)

# %%
train_kp = pd.read_csv("outputs/keypoints/train_keypoints.csv")
test_kp = pd.read_csv("outputs/keypoints/test_keypoints.csv")

# %%
train_kp = add_angles(train_kp)
train_kp = label_form_by_video(train_kp)
#train_kp = label_form(train_kp)
test_kp = add_angles(test_kp)
test_kp = label_form_by_video(test_kp)
#test_kp = label_form(test_kp)

# %%
print(train_kp.groupby(["label", "form_label"]).size())
print(test_kp.groupby(["label", "form_label"]).size())
# Out:
# label          form_label
# jumping_jacks  bad            276
#                good          2007
# lunges         bad           2657
#                good          5907
# pullups        bad            308
#                good          2511
# pushups        bad            666
#                good          1645
# squats         bad           1343
#                good          3969
# dtype: int64
# label          form_label
# jumping_jacks  bad            297
#                good           674
# lunges         bad           1700
#                good          1252
# pullups        bad             13
#                good           924
# pushups        bad            250
#                good           730
# squats         bad            943
#                good           869
# dtype: int64

# %% [markdown]
# Once we adjusted form rules to provide an approximately even distribution of good form/bad form for each exercise, we further classified bad form labels using more detailed constraints.

# %%
# Each exercise has a list of labels and conditions that are checked in priority order
DETAILED_FORM_RULES = {
    "squats": [
        ("squats_knees_caving", lambda r: abs(r["left_knee_bend"]) > 0.01 and abs(r["right_knee_bend"]) > 0.01),
        ("squats_not_deep_enough", lambda r: min(r["left_knee_angle"], r["right_knee_angle"]) > 150),
        ("squats_knees_caving", lambda r: True)  # Catch all
    ],
    "pushups": [
        ("pushups_back_too_low", lambda r: abs(r["left_body_line"] - 180) > 30 or abs(r["right_body_line"] - 180) > 30),
        ("pushups_hips_too_high", lambda r: r["left_body_line"] > 200 or r["right_body_line"] > 200),
        ("pushups_elbows_flaring", lambda r: r["arm_symmetry"] > 25),
        ("pushups_head_dropping", lambda r: r["head_drop"] > 0.1),
        ("pushups_back_too_low", lambda r: True) # Catch all
    ],
    "pullups": [
        ("pullups_shoulders_shrugging", lambda r: r["left_shoulder_shrug"] > -0.03 and r["right_shoulder_shrug"] > -0.03),
        ("pullups_incomplete_range", lambda r: min(r["left_elbow_angle"], r["right_elbow_angle"]) > 140),
        ("pullups_not_high_enough", lambda r: min(r["left_elbow_angle"], r["right_elbow_angle"]) > 110),
        ("pullups_shoulders_shrugging", lambda r: True) # Catch all
    ],
    "lunges": [
        ("lunges_torso_leaning", lambda r: r["torso_angle"] < 160),
        ("lunges_knees_caving", lambda r: abs(r["left_knee_bend"]) > 0.03 and abs(r["right_knee_bend"]) > 0.03 ),
        ("lunges_not_deep_enough", lambda r: min(r["left_knee_angle"], r["right_knee_angle"]) > 160),
        ("lunges_uneven_hips", lambda r: r["hip_symmetry"] > 15),
        ("lunges_torso_leaning", lambda r: True) # Catch all
    ],
    "jumping_jacks": [
        ("jumping_jacks_arms_not_extended", lambda r: min(r["left_elbow_angle"], r["right_elbow_angle"]) < 140),
        ("jumping_jacks_uneven_arms", lambda r: r["arm_symmetry"] > 10),
        ("jumping_jacks_feet_too_narrow", lambda r: r["leg_symmetry"] > 10),
        ("jumping_jacks_uneven_legs", lambda r: abs(r["left_knee_angle"] - r["right_knee_angle"]) > 20),
        ("jumping_jacks_arms_not_extended", lambda r: True) # Catch all
    ]
}

# %%
def detailed_form_labels(row):
    if (row["form_label"] == "good"):
        return f"{row['label']}_good"
    
    exercise = row["label"]
    rules = DETAILED_FORM_RULES.get(exercise, [])
    for label, condition in rules:
        try:
            if condition(row):
                return label
        except:
            continue
    return f"{exercise}_bad"

# %%
train_kp["class_label"] = train_kp.apply(detailed_form_labels, axis=1)
print(train_kp["class_label"].value_counts())

test_kp["class_label"] = test_kp.apply(detailed_form_labels, axis=1)
print(test_kp["class_label"].value_counts())
# Out:
# class_label
# lunges_good                        2760
# squats_good                        2724
# jumping_jacks_good                 2190
# lunges_not_deep_enough             2040
# squats_knees_caving                2014
# lunges_uneven_hips                 1932
# pullups_good                       1709
# pushups_back_too_low               1123
# lunges_torso_leaning                943
# lunges_knees_caving                 889
# pushups_good                        739
# squats_not_deep_enough              574
# pullups_shoulders_shrugging         541
# pullups_incomplete_range            430
# pushups_elbows_flaring              232
# pushups_head_dropping               217
# pullups_not_high_enough             139
# jumping_jacks_arms_not_extended      71
# jumping_jacks_uneven_arms            18
# jumping_jacks_feet_too_narrow         4
# Name: count, dtype: int64
# class_label
# squats_knees_caving                1214
# lunges_good                        1140
# jumping_jacks_good                  788
# lunges_uneven_hips                  754
# pushups_back_too_low                613
# pullups_good                        434
# lunges_torso_leaning                376
# squats_not_deep_enough              368
# lunges_not_deep_enough              347
# lunges_knees_caving                 335
# pullups_incomplete_range            286
# squats_good                         230
# pullups_shoulders_shrugging         173
# pushups_good                        173
# jumping_jacks_arms_not_extended     156
# pushups_elbows_flaring              127
# pushups_head_dropping                67
# pullups_not_high_enough              44
# jumping_jacks_feet_too_narrow        16
# jumping_jacks_uneven_arms            11
# Name: count, dtype: int64

# %%
train_pct = train_kp["class_label"].value_counts(normalize=True) * 100
test_pct  = test_kp["class_label"].value_counts(normalize=True)  * 100

comparison = pd.DataFrame({"train %": train_pct, "test %": test_pct}).round(1)
print(comparison)
# Out:
#                                  train %  test %
# class_label
# jumping_jacks_arms_not_extended      0.3     2.0
# jumping_jacks_feet_too_narrow        0.0     0.2
# jumping_jacks_good                  10.3    10.3
# jumping_jacks_uneven_arms            0.1     0.1
# lunges_good                         13.0    14.9
# lunges_knees_caving                  4.2     4.4
# lunges_not_deep_enough               9.6     4.5
# lunges_torso_leaning                 4.4     4.9
# lunges_uneven_hips                   9.1     9.9
# pullups_good                         8.0     5.7
# pullups_incomplete_range             2.0     3.7
# pullups_not_high_enough              0.7     0.6
# pullups_shoulders_shrugging          2.5     2.3
# pushups_back_too_low                 5.3     8.0
# pushups_elbows_flaring               1.1     1.7
# pushups_good                         3.5     2.3
# pushups_head_dropping                1.0     0.9
# squats_good                         12.8     3.0
# squats_knees_caving                  9.5    15.9
# squats_not_deep_enough               2.7     4.8

# %% [markdown]
# Convert both dataframes back to .csv form for training.

# %%
train_kp.to_csv("outputs/features/train_features.csv", index=False)
test_kp.to_csv("outputs/features/test_features.csv", index=False)

# %% [markdown]
# ## Training Phase
# ### We used MLP to train as our features are represented by vectors instead of images (pixels) ... better explanation coming

# %%
# Load necessary packages
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
import random

def visualize_labels(df, class_label, n=9):
    """
    Show n random frames for a given class label
    with the label and key feature values overlaid
    """
    subset = df[df["class_label"] == class_label].sample(min(n, len(df[df["class_label"] == class_label])))
    
    fig, axes = plt.subplots(3, 3, figsize=(12, 10))
    fig.suptitle(class_label, fontsize=14, fontweight="bold")
    axes = axes.flatten()

    for i, (_, row) in enumerate(subset.iterrows()):
        frame = cv2.imread(row["frame_path"])
        if frame is None:
            axes[i].set_visible(False)
            continue

        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        axes[i].imshow(frame)
        axes[i].axis("off")

        # Show relevant feature values per exercise
        label = row["label"]
        if label == "squats":
            info = f"knee_L={row['left_knee_angle']:.0f} knee_R={row['right_knee_angle']:.0f}\ntorso={row['torso_angle']:.0f}"
        elif label == "pushups":
            info = f"body_L={row['left_body_line']:.0f} body_R={row['right_body_line']:.0f}\nhead_drop={row['head_drop']:.2f}"
        elif label == "lunges":
            info = f"knee_L={row['left_knee_angle']:.0f} knee_R={row['right_knee_angle']:.0f}\ntorso={row['torso_angle']:.0f}"
        elif label == "pullups":
            info = f"elbow_L={row['left_elbow_angle']:.0f} elbow_R={row['right_elbow_angle']:.0f}\nshrug_L={row['left_shoulder_shrug']:.2f}"
        elif label == "jumping_jacks":
            info = f"arm_sym={row['arm_symmetry']:.0f} leg_sym={row['leg_symmetry']:.0f}"
        else:
            info = ""

        axes[i].set_title(info, fontsize=8)

    plt.tight_layout()
    plt.show()


# Check each class one by one
for label in train_kp["class_label"].unique():
    visualize_labels(train_kp, label, n=9)
    input(f"Press Enter to see next class...")  # pause between classes
# Out:
# [ WARN:0@324.089] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g16_c02\frame_0013.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@324.089] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g18_c02\frame_0012.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@324.089] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g18_c02\frame_0072.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@324.090] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g18_c01\frame_0053.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@324.090] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g09_c04\frame_0061.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@324.090] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g19_c02\frame_0024.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@324.091] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g18_c04\frame_0036.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@324.091] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g19_c02\frame_0023.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@324.091] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g15_c02\frame_0040.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@326.625] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g17_c03\frame_0065.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@326.626] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g08_c04\frame_0045.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@326.626] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g17_c03\frame_0067.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@326.627] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g25_c01\frame_0005.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@326.627] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g19_c04\frame_0037.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@326.627] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g17_c04\frame_0040.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@326.627] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g24_c04\frame_0016.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@326.627] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g20_c03\frame_0007.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@326.628] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g08_c02\frame_0006.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@350.412] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g11_c01\frame_0012.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@350.413] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g20_c04\frame_0050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@350.413] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g12_c03\frame_0011.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@350.414] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g20_c05\frame_0041.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@350.414] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g10_c05\frame_0041.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@350.414] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g19_c04\frame_0010.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@350.414] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g12_c03\frame_0052.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@350.415] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g24_c01\frame_0008.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@350.415] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\squats\v_BodyWeightSquats_g24_c05\frame_0000.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@351.158] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g24_c02\frame_0029.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.158] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g12_c03\frame_0001.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.158] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g17_c04\frame_0011.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.159] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g19_c06\frame_0004.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.159] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g20_c04\frame_0007.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.159] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g20_c04\frame_0031.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.160] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g21_c03\frame_0012.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.160] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g13_c04\frame_0019.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.160] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g18_c03\frame_0031.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@351.723] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g10_c03\frame_0010.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.724] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g10_c01\frame_0016.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.724] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g11_c02\frame_0015.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.725] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g10_c01\frame_0017.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.725] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g10_c03\frame_0009.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.725] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g10_c01\frame_0018.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.725] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g11_c03\frame_0008.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.726] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g23_c03\frame_0021.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@351.726] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g11_c03\frame_0017.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@352.414] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g10_c01\frame_0015.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@352.415] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g10_c03\frame_0008.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@352.415] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g23_c03\frame_0008.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@352.415] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g11_c03\frame_0001.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@352.416] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g10_c01\frame_0007.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@352.416] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g11_c03\frame_0024.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@352.416] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g23_c03\frame_0006.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@352.417] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g10_c03\frame_0014.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@352.417] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g10_c03\frame_0006.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@352.998] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g10_c03\frame_0021.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@352.998] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g23_c03\frame_0020.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@352.998] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g11_c03\frame_0026.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@352.999] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\jumping_jacks\v_JumpingJack_g10_c01\frame_0022.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@357.097] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g13_c02\frame_0008.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.098] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g11_c05\frame_0097.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.098] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g10_c06\frame_0093.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.099] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g25_c01\frame_0007.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.099] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g13_c01\frame_0026.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.099] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g22_c03\frame_0017.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.100] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g19_c02\frame_0028.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.100] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g12_c01\frame_0053.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.100] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g19_c02\frame_0112.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@357.854] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g18_c04\frame_0071.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.855] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g18_c02\frame_0086.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.855] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g14_c07\frame_0074.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.856] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g18_c03\frame_0054.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.856] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g14_c07\frame_0084.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.856] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g18_c05\frame_0057.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.856] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g18_c02\frame_0118.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.857] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g18_c03\frame_0095.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@357.857] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g08_c01\frame_0071.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@358.698] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g23_c04\frame_0046.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@358.699] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g17_c04\frame_0025.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@358.699] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g17_c04\frame_0118.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@358.699] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g20_c02\frame_0007.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@358.700] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g24_c03\frame_0079.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@358.700] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g12_c03\frame_0044.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@358.700] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g18_c03\frame_0050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@358.701] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g12_c03\frame_0013.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@358.701] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g10_c05\frame_0110.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@359.540] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g24_c04\frame_0075.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@359.540] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g10_c04\frame_0001.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@359.540] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g11_c05\frame_0078.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@359.541] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g23_c04\frame_0049.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@359.541] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g10_c03\frame_0100.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@359.541] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g12_c03\frame_0023.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@359.541] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g23_c01\frame_0010.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@359.542] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g17_c04\frame_0037.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@359.542] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g11_c05\frame_0068.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@360.504] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g13_c05\frame_0124.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@360.504] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g14_c01\frame_0064.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@360.504] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g21_c03\frame_0030.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@360.505] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g13_c05\frame_0040.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@360.505] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g14_c01\frame_0124.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@360.505] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g25_c04\frame_0069.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@360.505] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g14_c03\frame_0130.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@360.506] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g14_c06\frame_0075.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@360.506] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\lunges\v_Lunges_g14_c03\frame_0112.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@361.154] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g24_c04\frame_0013.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@361.154] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g23_c01\frame_0022.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@361.154] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g24_c04\frame_0062.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@361.155] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g15_c03\frame_0032.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@361.155] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g24_c04\frame_0025.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@361.155] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g21_c02\frame_0023.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@361.155] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g23_c01\frame_0001.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@361.156] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g23_c01\frame_0032.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@361.156] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g09_c04\frame_0000.jpg'): can't open/read file: check file path/integrity
# Press Enter to see next class...
# [ WARN:0@362.192] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g15_c03\frame_0006.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@362.193] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g13_c04\frame_0016.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@362.193] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g23_c04\frame_0015.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@362.193] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g11_c01\frame_0004.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@362.194] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g09_c01\frame_0009.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@362.194] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g23_c04\frame_0040.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@362.194] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g09_c01\frame_0033.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@362.194] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g24_c02\frame_0053.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@362.195] global loadsave.cpp:278 findDecoder imread_('outputs/frames\train\pullups\v_PullUps_g08_c01\frame_0020.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 48
#      46 for label in train_kp["class_label"].unique():
#      47     visualize_labels(train_kp, label, n=9)
# ---> 48     input(f"Press Enter to see next class...")  # pause between classes
#
# File /opt/conda/lib/python3.11/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File /opt/conda/lib/python3.11/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
